# %%
import pandas as pd

# %%
#Import Data
data = pd.read_csv('~/Downloads/HPD_Crime_Incidents.csv')
#Sort
sortdata = data.sort_values(by = ['BlockAddress','Type'],ignore_index=True)
#Create a new column that ASC counts the row 
#sorbycrime['new index'] = range(len(sorbycrime))
#Set the Created column as the index
#crime = sorbycrime.set_index('new index')
#Check your new index
#crime.loc[0:10]

# %%
data.head()
# Out:
#    ObjectID          KiloNBR                 BlockAddress  \
# 0   1406586  LHP190728000166            200 BLOCK H1E FWY
# 1   1406596  LHP190728000247            200 BLOCK H1E FWY
# 2   1406662  LHP190728001087            0 BLOCK VINSON RD
# 3   1406764  LHP190729000710       911100 BLOCK KANELA ST
# 4   1406778  LHP190729000833  200 BLOCK AMELIA EARHART RD
#
#                                  CMID         CMAgency  \
# 0  Honolulu_PD_HI_LHP190728000166_210  Honolulu PD, HI
# 1  Honolulu_PD_HI_LHP190728000247_210  Honolulu PD, HI
# 2  Honolulu_PD_HI_LHP190728001087_077  Honolulu PD, HI
# 3  Honolulu_PD_HI_LHP190729000710_060  Honolulu PD, HI
# 4  Honolulu_PD_HI_LHP190729000833_064  Honolulu PD, HI
#
#                            Date                    Type Status  Score  Side
# 0  07/28/2019 12:12:00 PM +0000                     DUI      U      0     0
# 1  07/28/2019 01:55:00 PM +0000                     DUI      U      0     1
# ...

# %%
sortdata.head()
# Out:
#    ObjectID          KiloNBR      BlockAddress  \
# 0   1458031  LHP191008001076   0 BLOCK AHUI ST
# 1   1490712  LHP191202001716   0 BLOCK AHUI ST
# 2   1472929  LHP191111001154   0 BLOCK AHUI ST
# 3   1492393  LHP191204001204   0 BLOCK AHUI ST
# 4   1520368  LHP200108000509  0 BLOCK AKAMU PL
#
#                                  CMID         CMAgency  \
# 0  Honolulu_PD_HI_LHP191008001076_180  Honolulu PD, HI
# 1  Honolulu_PD_HI_LHP191202001716_060  Honolulu PD, HI
# 2  Honolulu_PD_HI_LHP191111001154_064  Honolulu PD, HI
# 3  Honolulu_PD_HI_LHP191204001204_064  Honolulu PD, HI
# 4  Honolulu_PD_HI_LHP200108000509_050  Honolulu PD, HI
#
#                            Date                      Type Status  Score   Side
# 0  10/09/2019 01:30:00 AM +0000  DRUGS/ALCOHOL VIOLATIONS      M    100  10012
# 1  12/03/2019 07:07:00 AM +0000             THEFT/LARCENY      M    100  15561
# 2  11/12/2019 02:39:00 AM +0000    VEHICLE BREAK-IN/THEFT      M    100  12582
# ...

# %% [markdown]
# Need to fix to be about orgainizing your pandas DataFrame or orginizing you data with python
#
#
# Back when I started importing new datasets sometimes I didn't really like the way they were ordered and so I would change how the data was sorted, but then I ran into the problem of not having the index matching my new order, which set off my ocd. So today I will give a quick example of reordering your data and setting a new index that matches your order.
#
# If you want to follow along with this example you can find this data located at ... under ... . From there if Downloads folder directly off of your (cant remember word for saved first location in terminal) you can just copy along exactly what I have, if not you will have to change the file path below to where you have the downloaded file saved.
#
# So first thing we are going to import the Pandas library for python because it is the best way to sort/ organize and create a DataFrame. Then we will have Pandas directly convert the .csv file to a DataFrame.
#
# Here we take a look at our DataFrame and see that our data is sorted by the ObjectID, which seems to be the crimes ordered by when they were filed. Though lets say we want the be able to scroll through our data have the crimes organize by what type of crime it was or by the location of the crime or even both.
#
# Sorting your pandas notebook is amazingly easy with the help of sort_values. Here all you need to do type in the name of your DataFrame followed by .sort_values followed with a by = 'name_of_column_to_sort_by' or even a python list of the columns you want to sort by in the order you want them sorted. It even gives you some hyperparameters to change your sorting by acending, decending
#
# Walk through hyperparameters
# by: string or list of string in the order of which ones you want the data to sort by first
# axis
# acending
# inplace=False,
# kind='quicksort',
# na_position='last',
# ignore_index=False,

# %%
add_column
# Out:
# range(0, 22373)

# %%
sorbycrime.loc[0:10]
# Out:
#     ObjectID          KiloNBR            BlockAddress  \
# 0    1458031  LHP191008001076         0 BLOCK AHUI ST
# 1    1490712  LHP191202001716         0 BLOCK AHUI ST
# 2    1472929  LHP191111001154         0 BLOCK AHUI ST
# 3    1492393  LHP191204001204         0 BLOCK AHUI ST
# 4    1520368  LHP200108000509        0 BLOCK AKAMU PL
# 5    1406746  LHP190729000412        0 BLOCK AKAMU PL
# 6    1528105  LHP200118000668  0 BLOCK ALOHA TOWER DR
# 7    1461958  LHP191029001725  0 BLOCK ALOHA TOWER DR
# 8    1464480  LHP191101000158  0 BLOCK ALOHA TOWER DR
# 9    1466245  LHP191103000956  0 BLOCK ALOHA TOWER DR
# 10   1502242  LHP191215001310  0 BLOCK ALOHA TOWER DR
#
#                                   CMID         CMAgency  \
# 0   Honolulu_PD_HI_LHP191008001076_180  Honolulu PD, HI
# 1   Honolulu_PD_HI_LHP191202001716_060  Honolulu PD, HI
# 2   Honolulu_PD_HI_LHP191111001154_064  Honolulu PD, HI
# 3   Honolulu_PD_HI_LHP191204001204_064  Honolulu PD, HI
# ...

# %%
someset.loc[0:10]
# Out:
#     ObjectID          KiloNBR                 BlockAddress  \
# 0    1406586  LHP190728000166            200 BLOCK H1E FWY
# 1    1406596  LHP190728000247            200 BLOCK H1E FWY
# 2    1406662  LHP190728001087            0 BLOCK VINSON RD
# 3    1406764  LHP190729000710       911100 BLOCK KANELA ST
# 4    1406778  LHP190729000833  200 BLOCK AMELIA EARHART RD
# 5    1406802  LHP190729001150        4200 BLOCK RADFORD DR
# 6    1406809  LHP190729001251  0 BLOCK ARIZONA MEMORIAL PL
# 7    1406829  LHP190729001559            900 BLOCK KUOU ST
# 8    1407401  LHP190730000606               KUNIA ONTO H1E
# 9    1407417  LHP190730000752     0 BLOCK BELLEAU WOODS ST
# 10   1407470  LHP190730001371     951000 BLOCK MELEKOMO ST
#
#                                   CMID         CMAgency  \
# 0   Honolulu_PD_HI_LHP190728000166_210  Honolulu PD, HI
# 1   Honolulu_PD_HI_LHP190728000247_210  Honolulu PD, HI
# 2   Honolulu_PD_HI_LHP190728001087_077  Honolulu PD, HI
# ...
