# %%
import pandas as pd
import pandasql as ps
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
cb = "///Users/timothycummins/Downloads/579969-1411956-bundle-archive/us_county.shp"
dbcb = gpd.read_file(cb)

# %%
dbcb.plot()

# %%
csv1 = "///Users/timothycummins/Downloads/579969-1411956-bundle-archive/us_county.csv"
db1=pd.read_csv(csv1)

# %%
db1.head()
# Out:
#    fips          county    state state_code    male  female  median_age  \
# 0  1001  Autauga County  Alabama         AL   26874   28326        37.8
# 1  1003  Baldwin County  Alabama         AL  101188  106919        42.8
# 2  1005  Barbour County  Alabama         AL   13697   12085        39.9
# 3  1007     Bibb County  Alabama         AL   12152   10375        39.9
# 4  1009   Blount County  Alabama         AL   28434   29211        40.8
#
#    population  female_percentage        lat       long
# 0       55200          51.315217  32.534923 -86.642730
# 1      208107          51.376936  30.727479 -87.722564
# 2       25782          46.873788  31.869581 -85.393210
# 3       22527          46.055844  32.998628 -87.126475
# 4       57645          50.673953  33.980869 -86.567380

# %%
csv2 = "data/covid_us_county.csv"
db2=pd.read_csv(csv2)

# %%
q1 = ("""
SELECT SUM(deaths) deaths, state_code, cases, fips
FROM db2
WHERE deaths > 1 and date is '2020-08-10'
GROUP BY fips
""")
df = ps.sqldf(q1)

# %%
df
# Out:
#       deaths state_code  cases     fips
# 0        197         MO   6786      NaN
# 1          5       None    418     66.0
# 2          2       None     49     69.0
# 3          9       None    547     78.0
# 4         21         AL   1174   1001.0
# ...      ...        ...    ...      ...
# 1962       4         TN   3142  90047.0
# 1963     239         TX      0  90048.0
# 1964       2         WA    202  90053.0
# 1965      27         WY      0  90056.0
# 1966       3       None    103  99999.0
#
# [1967 rows x 4 columns]

# %%
q1 = ("""
SELECT *
FROM db2
WHERE state_code like "WA"
ORDER BY date desc
""")
ps.sqldf(q1)
# Out:
#          fips      county       state        lat        long        date  \
# 0     53001.0       Adams  Washington  46.982998 -118.560173  2020-08-10
# 1     53003.0      Asotin  Washington  46.188944 -117.202285  2020-08-10
# 2     53005.0      Benton  Washington  46.239470 -119.512083  2020-08-10
# 3     53007.0      Chelan  Washington  47.870461 -120.617396  2020-08-10
# 4     53009.0     Clallam  Washington  48.047546 -123.922632  2020-08-10
# ...       ...         ...         ...        ...         ...         ...
# 8277  53073.0     Whatcom  Washington  48.822280 -121.749002  2020-01-22
# 8278  53075.0     Whitman  Washington  46.900225 -117.524176  2020-01-22
# 8279  53077.0      Yakima  Washington  46.457385 -120.738013  2020-01-22
# 8280  80053.0   Out of WA  Washington   0.000000    0.000000  2020-01-22
# 8281  90053.0  Unassigned  Washington   0.000000    0.000000  2020-01-22
#
#       cases state_code  deaths
# 0       452         WA       5
# 1        27         WA       2
# 2      3748         WA     116
# 3      1358         WA      10
# 4       122         WA       0
# ...     ...        ...     ...
# 8277      0         WA       0
# 8278      0         WA       0
# 8279      0         WA       0
# 8280      0         WA       0
# 8281      0         WA       0
#
# [8282 rows x 9 columns]

# %%
df.dropna(inplace=True)

# %%
df['fips']=df['fips'].astype('int32')

# %%
df
# Out:
#       deaths state_code  cases   fips
# 4         21         AL   1174   1001
# 5         25         AL   3651   1003
# 6          5         AL    576   1005
# 7          5         AL    442   1007
# 8          4         AL    812   1009
# ...      ...        ...    ...    ...
# 1961    1015         RI   2074  90044
# 1962       4         TN   3142  90047
# 1963     239         TX      0  90048
# 1964       2         WA    202  90053
# 1965      27         WY      0  90056
#
# [1960 rows x 4 columns]

# %%
dbcb
# Out:
#         fips                                           geometry
# 0      01001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 1      01001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 2      01001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 3      01001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 4      01003  POLYGON ((-88.02858 30.22676, -88.02399 30.230...
# ...      ...                                                ...
# 12875  72151  POLYGON ((-66.01040 18.07201, -66.00861 18.073...
# 12876  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
# 12877  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
# 12878  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
# 12879  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
#
# [12880 rows x 2 columns]

# %%
dbcb['fips']=dbcb['fips'].astype('int32')

# %%
dbcb
# Out:
#         fips                                           geometry
# 0       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 1       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 2       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 3       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 4       1003  POLYGON ((-88.02858 30.22676, -88.02399 30.230...
# ...      ...                                                ...
# 12875  72151  POLYGON ((-66.01040 18.07201, -66.00861 18.073...
# 12876  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
# 12877  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
# 12878  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
# 12879  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...
#
# [12880 rows x 2 columns]

# %%
merged=pd.merge(dbcb,df,how='left',on='fips')

# %%
merged['deaths']=merged['deaths'].fillna(0)

# %%
merged
# Out:
#         fips                                           geometry  deaths  \
# 0       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...    21.0
# 1       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...    21.0
# 2       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...    21.0
# 3       1001  POLYGON ((-86.92120 32.65754, -86.92035 32.658...    21.0
# 4       1003  POLYGON ((-88.02858 30.22676, -88.02399 30.230...    25.0
# ...      ...                                                ...     ...
# 12875  72151  POLYGON ((-66.01040 18.07201, -66.00861 18.073...     0.0
# 12876  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...     0.0
# 12877  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...     0.0
# 12878  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...     0.0
# 12879  72153  POLYGON ((-66.92652 18.15127, -66.92143 18.152...     0.0
#
#       state_code   cases
# 0             AL  1174.0
# 1             AL  1174.0
# 2             AL  1174.0
# 3             AL  1174.0
# 4             AL  3651.0
# ...          ...     ...
# 12875        NaN     NaN
# 12876        NaN     NaN
# 12877        NaN     NaN
# 12878        NaN     NaN
# 12879        NaN     NaN
#
# [12880 rows x 5 columns]

# %%
plt.rcParams['figure.figsize'] = [9, 6] 

vmin, vmax = .1, .67

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(14,6))

# remove the axis
ax.axis('off')

# add a title and annotation
ax.set_title('deaths', fontdict={'fontsize': '25', 'fontweight' : '3'})

# Create colorbar legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm.set_array([])

cbar = fig.colorbar(sm)
cbar.set_ticks([.2,.3, .4, .5, .6])
cbar.set_ticklabels(['20%', '30%', '40%', '50%','60%'])
# create map
merged.plot(column=(merged['deaths']), cmap='Blues', linewidth=0.8, ax=ax, edgecolor='1')
