# %% [markdown]
# Question 1: Given some sample data, write a program to answer the following: click here to access the required data set
#
# On Shopify, we have exactly 100 sneaker shops, and each of these shops sells only one model of shoe. We want to do some analysis of the average order value (AOV). When we look at orders data over a 30 day window, we naively calculate an AOV of $3145.13. Given that we know these shops are selling sneakers, a relatively affordable item, something seems wrong with our analysis.
#
# 1)Think about what could be going wrong with our calculation. Think about a better way to evaluate this data.
#
# 2)What metric would you report for this dataset?
#
# 3)What is its value?

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('~/Downloads/InternData.csv')

# %%
data.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %%
data.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %%
sortdata = data.sort_values(by = ['order_amount','created_at'],ascending=False,ignore_index=True)

# %%
sortdata.head(20)
# Out:
#     order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0       2836       42      607        704000         2000    credit_card
# 1       2970       42      607        704000         2000    credit_card
# 2       4057       42      607        704000         2000    credit_card
# 3       4883       42      607        704000         2000    credit_card
# 4       1105       42      607        704000         2000    credit_card
# 5       3333       42      607        704000         2000    credit_card
# 6       4869       42      607        704000         2000    credit_card
# 7       1563       42      607        704000         2000    credit_card
# 8       1603       42      607        704000         2000    credit_card
# 9       1363       42      607        704000         2000    credit_card
# 10      2154       42      607        704000         2000    credit_card
# 11      1437       42      607        704000         2000    credit_card
# ...

# %%
data['order_amount']
# Out:
# <bound method hist_series of 0       224
# 1        90
# 2       144
# 3       156
# 4       156
#        ...
# 4995    330
# 4996    234
# 4997    351
# 4998    354
# 4999    288
# Name: order_amount, Length: 5000, dtype: int64>

# %%
fig, axes = plt.subplots(figsize=(12,6))
sbn.distplot((data['total_items']), ax=axes)

# %%
data.boxplot()

# %%
data[data['user_id']==607]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %%
df = data[data['user_id']!=607]

# %%
df.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  4983.000000  4983.000000  4983.000000    4983.000000   4983.00000
# mean   2501.060405    50.106362   849.918322     754.091913      1.99398
# std    1443.090253    29.051718    86.800308    5314.092293      0.98318
# min       1.000000     1.000000   700.000000      90.000000      1.00000
# 25%    1250.500000    24.000000   776.000000     163.000000      1.00000
# 50%    2502.000000    50.000000   850.000000     284.000000      2.00000
# 75%    3750.500000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  154350.000000      8.00000

# %%
sortdata2 = df.sort_values(by = ['order_amount','created_at'],ascending=False,ignore_index=True)

# %%
sortdata2.head(50)
# Out:
#     order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0        692       78      878        154350            6          debit
# 1       2493       78      834        102900            4          debit
# 2       1260       78      775         77175            3    credit_card
# 3       2565       78      915         77175            3          debit
# 4       2691       78      962         77175            3          debit
# 5       4193       78      787         77175            3    credit_card
# 6       3404       78      928         77175            3          debit
# 7       2907       78      817         77175            3          debit
# 8       3725       78      766         77175            3    credit_card
# 9       4421       78      969         77175            3          debit
# 10      4716       78      818         77175            3          debit
# 11      1530       78      810         51450            2           cash
# ...

# %%
fig, axes = plt.subplots(figsize=(12,6))
sbn.distplot((df['total_items']), ax=axes)

# %%
df['order_amount'].hist()

# %%
sortdata3 = df.sort_values(by = ['created_at'],ascending=False,ignore_index=True)

# %%
sortdata3
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0          146       72      906           640            4           cash
# 1          212       22      712           292            2    credit_card
# 2          245       32      928           202            2           cash
# 3         4891       63      853           136            1           cash
# 4         2766        9      708           236            2          debit
# ...        ...      ...      ...           ...          ...            ...
# 4978      2690       49      799           258            2    credit_card
# 4979      1268       80      798           290            2    credit_card
# 4980      3229       97      912           324            2           cash
# 4981      1742       39      910           268            2           cash
# 4982      1863       39      738           536            4           cash
#
#               created_at
# 0     2017-03-30 9:55:00
# ...
